# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('netflix1.csv')
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.shape #no. of rows and column
# Out:
# (7789, 11)

# %%
df.columns #check all names
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df[df.duplicated()] #check duplicated values
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
df.isnull().sum() #check null values
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
plt.figure(figsize=[10,6])
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df[df['Title'].isin(['Jalpari: The Desert Mermaid'])] #show all records of partcular column
# Out:
#      Show_Id Category                        Title           Director  \
# 3117   s3118    Movie  Jalpari: The Desert Mermaid  Nila Madhab Panda
#
#                                                    Cast Country  Release_Date  \
# 3117  Lehar Khan, Krishang Trivedi, Parvin Dabas, Su...   India  May 19, 2018
#
#      Rating Duration                                              Type  \
# 3117  TV-14   94 min  Dramas, Independent Movies, International Movies
#
#                                             Description
# 3117  When they travel to their father's ancestral v...

# %%
#In which year highest number of TV Shows and Movies were released? Show with bar graph.
#Formatting release date column
df['Date']=pd.to_datetime(df['Release_Date'])
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df['Date'].dt.year.value_counts() #using value_counts() function to know which year highest TV Shows and Movies were released.
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date, dtype: int64

# %%
df['Date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#How many movies and shows are in the dataset? Show with the bar graph
df['Category'].value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
#Show only the titles of all the TV Shows that were released in Pakistan.
df[(df['Category']=='TV Show')&(df['Country']=='Pakistan')]['Title']
# Out:
# 2864              Humsafar
# 3352                Khaani
# 5338        Sadqay Tumhare
# 7769    Zindagi Gulzar Hai
# Name: Title, dtype: object

# %%
#Show only the titles of all the Movies that were released in India.

df[(df['Category']=='Movie')&(df['Country']=='India')]['Title']
# Out:
# 8                            706
# 9                           1920
# 18                        15-Aug
# 20          ​​Kuch Bheege Alfaaz
# 21                  ​Goli Soda 2
#                   ...
# 7766                        Zero
# 7771    Zindagi Na Milegi Dobara
# 7778                    Zokkomon
# 7782                         Zoo
# 7785                      Zubaan
# Name: Title, Length: 852, dtype: object

# %%
df['Director'].value_counts().head(6)
#Show top 6 directors who gave highest number of TV Shows and Movies to Netflix.
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Name: Director, dtype: int64

# %%
#Show all the records where ‘Category is Movies and Type is Comedies’ or ‘Country is United states.
df[(df['Category']=='Movies')&(df['Type']=='Comedies') | (df['Country']=='United States')].head()
# Out:
#    Show_Id Category Title        Director  \
# 3       s4    Movie     9     Shane Acker
# 4       s5    Movie    21  Robert Luketic
# 7       s8    Movie   187  Kevin Reynolds
# 10     s11    Movie  1922    Zak Hilditch
# 14     s15    Movie  3022      John Suits
#
#                                                  Cast        Country  \
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 7   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 10  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...  United States
# 14  Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...  United States
#
#          Release_Date Rating Duration  \
# 3   November 16, 2017  PG-13   80 min
# 4     January 1, 2020  PG-13  123 min
# 7    November 1, 2019      R  119 min
# 10   October 20, 2017  TV-MA  103 min
# 14     March 19, 2020      R   91 min
#
# ...

# %%
#Drop the null values from the dataset with the help of dropna() function
df1=df.dropna()
df1.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
#In how many TV Shows/Movies Amna Khalil was casted?
df1[df1['Cast'].str.contains('Amina Khalil')]
# Out:
#      Show_Id Category     Title         Director  \
# 6         s7    Movie       122  Yasir Al Yasiri
# 6205   s6205    Movie  The Cell   Tarek Al Eryan
# 6913   s6912    Movie  The Suit    Mohammad Adel
#
#                                                    Cast Country  \
# 6     Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...   Egypt
# 6205  Ahmed Ezz, Mohamed Mamdouh, Samer al Masri, Am...   Egypt
# 6913  Tamer Hosny, Akram Hosny, Amina Khalil, Dalal ...   Egypt
#
#            Release_Date Rating Duration  \
# 6          June 1, 2020  TV-MA   95 min
# 6205      June 13, 2019  TV-MA  126 min
# 6913  November 23, 2020  TV-14   97 min
#
#                                                    Type  \
# 6                   Horror Movies, International Movies
# 6205   Action & Adventure, Dramas, International Movies
# 6913  Action & Adventure, Comedies, International Mo...
#
#                                             Description
# ...

# %%
#What are the different rating defined by Netflix, and how many Movies got TV-14 Rating in United States?

df1['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#how many Movies got TV-14 Rating in United States?
df1[(df1['Rating']=='TV-14')&(df1['Country']=='United States')]
# Out:
#      Show_Id Category                                   Title  \
# 33       s34    Movie                            #realityhigh
# 47       s48    Movie                           1 Mile to You
# 184     s185    Movie  A Haunting at Silver Falls: The Return
# 232     s233    Movie              A Stoning in Fulham County
# 247     s248    Movie                 A Very Murray Christmas
# ...      ...      ...                                     ...
# 7563   s7562    Movie                      What Still Remains
# 7571   s7570    Movie             What Would Sophia Loren Do?
# 7588   s7587    Movie                       When We First Met
# 7644   s7643    Movie                                Wish Man
# 7664   s7663    Movie                                 Work It
#
#               Director                                               Cast  \
# 33    Fernando Lebrija  Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...

# %%
#how many Movies got TV-14 Rating in pakistan?
df1[(df1['Rating']=='TV-14')&(df1['Country']=='Pakistan')]
# Out:
#      Show_Id Category                        Title            Director  \
# 282     s283    Movie  Abdullah, The Final Witness  Hashim Nadeem Khan
# 1263   s1264    Movie            Chalay Thay Saath           Umer Adil
# 1384   s1385    Movie                Chupan Chupai          Mohsin Ali
# 3120   s3121    Movie                       Janaan         Azfar Jafri
# 4775   s4776    Movie                         Pari       Syed Atif Ali
# 5101   s5101    Movie                     Rangreza      Amir Mohiuddin
# 5329   s5329    Movie                       Saawan         Farhan Alam
# 6008   s6008    Movie             Teefa in Trouble         Ahsan Rahim
# 7677   s7676    Movie                    Wrong No.         Yasir Nawaz
# 7770   s7769    Movie     Zindagi Kitni Haseen Hay       Anjum Shahzad
#
#                                                    Cast   Country  \
# 282   Sajid Hasan, Hameed Sheikh, Habibullah Panezai...  Pakistan
# ...

# %%
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# 22       s23    Movie        ​Maj Rati ​​Keteki   Santwana Bardoloi
# ...      ...      ...                       ...                 ...
# 7756   s7755    Movie                      Yuva         Mani Ratnam
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %%
#Which country has the highest no. of TV Shows? Show with the bar graph.
tvshow=df1[df1['Category']=='TV Show']
tvshow.head()
# Out:
#     Show_Id Category            Title       Director  \
# 5        s6  TV Show               46    Serdar Akar
# 132    s133  TV Show        7 (Seven)    Nizar Shafi
# 218    s219  TV Show  A Queen Is Born   Carla Barros
# 260    s261  TV Show         A.I.C.O.  Kazuya Murata
# 276    s277  TV Show     Abby Hatcher    Kyran Kelly
#
#                                                   Cast                Country  \
# 5    Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...                 Turkey
# 132  Rahman, Havish, Regina Cassandra, Nandita Swet...                  India
# 218                      Gloria Groove, Alexia Twister                 Brazil
# 260  Haruka Shiraishi, Yusuke Kobayashi, Makoto Fur...                  Japan
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
#
#           Release_Date Rating  Duration  \
# 5         July 1, 2017  TV-MA  1 Season
# 132      July 30, 2019  TV-14  1 Season
# 218  November 11, 2020  TV-14  1 Season
# ...

# %%
tvshow.Country.value_counts().head()
# Out:
# United States     1628
# India              827
# United Kingdom     155
# Canada             101
# Egypt               87
# Name: Country, dtype: int64

# %%
#Which country has the highest no. of Movies? Show with the bar graph.
tvshow1 = df1[(df1['Category'] == 'Movie') | (df1['Category'] == 'TV Show')]
tvshow1.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
tvshow1.Country.value_counts().head()
# Out:
# United States     1628
# India              827
# United Kingdom     155
# Canada             101
# Egypt               87
# Name: Country, dtype: int64

# %%
plt.figure(figsize=[10,4])
tvshow1.Category.value_counts().plot(kind='bar', width=0.2)
plt.show()
